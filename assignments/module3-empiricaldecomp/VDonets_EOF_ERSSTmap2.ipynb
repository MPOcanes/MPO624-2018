# %% [markdown]
# <a name="top"></a>
# <div style="width:1000 px">
#
# <div style="float:right; width:98 px; height:98px;">
# <img src="https://cdn.miami.edu/_assets-common/images/system/um-logo-gray-bg.png" alt="Miami Logo" style="height: 98px;">
# </div>
#
# <h1>MPO 624: EOF analysis of monthly SST</h1>
# <h3>Uses OpenDAP link to ERSST online at NOAA-PSD</h3>
#
#
# <div style="clear:both"></div>
# </div>
#
# <hr style="height:2px;">
#
# ### Links to subsections
# 1. <a href="#opendap">OpenDAP: from a URL not a file. Examples of subsetting with xarray</a>
# 1. <a href="#eofs">Call the EOF package</a>
# 1. <a href="#eofpcplots">EOF x PC plots for a few top modes</a>
# 1. <a href="#orthogonality">Orthogonality check</a>

# %%
import xarray as xr 
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

dataset = xr.open_dataset('https://www.esrl.noaa.gov/psd/thredds/dodsC/Datasets/noaa.oisst.v2/sst.wkmean.1990-present.nc')

# %%
tropicsdata = dataset.sel(lat =slice(40,-40)) # notice LAT ARRAY IS INVERTED!

tropics9899 = dataset.sel(time=slice(datetime(2009,1,1),datetime(2009,12,1)))\
                     .sel(lat =slice(40,-40)) # LAT ARRAY IS INVERTED!
tropics9899
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 80, lon: 360, nbnds: 2, time: 48)
# Coordinates:
#   * lat        (lat) float32 39.5 38.5 37.5 36.5 35.5 34.5 33.5 32.5 31.5 ...
#   * lon        (lon) float32 0.5 1.5 2.5 3.5 4.5 5.5 6.5 7.5 8.5 9.5 10.5 ...
#   * time       (time) datetime64[ns] 2009-01-04 2009-01-11 2009-01-18 ...
# Dimensions without coordinates: nbnds
# Data variables:
#     time_bnds  (time, nbnds) float64 ...
#     sst        (time, lat, lon) float32 ...
# Attributes:
#     title:                           NOAA Optimum Interpolation (OI) SST V2
#     Conventions:                     CF-1.0
#     history:                         Created 10/2002 by RHS
#     comments:                        Data described in  Reynolds, R.W., N.A. ...
#     platform:                        Model
#     source:                          NCEP Climate Modeling Branch
#     institution:                     National Centers for Environmental Predi...
#     References:                      https://www.esrl.noaa.gov/psd/data/gridd...
#     NCO:                             4.0.0
#     dataset_title:                   NOAA Optimum Interpolation (OI) SST V2
#     source_url:                      http://www.emc.ncep.noaa.gov/research/cm...
#     DODS_EXTRA.Unlimited_Dimension:  time

# %%
NINOdata = dataset.sel(time=slice(datetime(2000,1,1),datetime(2017,12,1)))\
                  .sel(lat=0, lon=180, method='nearest')

# %matplotlib inline
NINOdata.sst.plot()

# %%
# CartoPy map plot at one time
import cartopy.crs as ccrs
import cartopy.feature as cfeat

fig = plt.figure(figsize=(10, 4))

ax = fig.add_subplot(111, projection=ccrs.PlateCarree())

# Sets the extent to cover the whole globe
# ax.set_global()

sst = ax.contourf(dataset.lon, dataset.lat, dataset.sel(time=datetime(1999,1,1), method='nearest').sst, 23,
                 transform=ccrs.PlateCarree(), 
                 cmap='jet')
ax.add_feature(cfeat.COASTLINE)
plt.colorbar(sst)

# %% [markdown]
# <a name="eofs"></a>
# ## Let's do an EOF analysis the easy way
# With a package, from our field
# https://openresearchsoftware.metajnl.com/articles/10.5334/jors.122/

# %%
from eofs.standard import Eof # import standard eofs from python eofs package, 
                              # to install eofs package use `conda install eofs` in environment you want to add it to
                              # for API see http://ajdawson.github.io/eofs/api/index.html for more information.

# %%
# Create an EOF solver to do the EOF analysis. Square-root of cosine of
# latitude weights (area weighting of variance) is applied before the computation of EOFs.
coslat = np.cos(np.deg2rad(tropiclat))
wgts = np.sqrt(coslat)[:, np.newaxis]
solver = Eof( tropics.data, wgts )

# Unweighted (just gridpoint variance)

solver = Eof( tropics9899.sst.data )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-35c5c096b093> in <module>()
#       1 # Create an EOF solver to do the EOF analysis. Square-root of cosine of
#       2 # latitude weights (area weighting of variance) is applied before the computation of EOFs.
# ----> 3 coslat = np.cos(np.deg2rad(tropiclat))
#       4 wgts = np.sqrt(coslat)[:, np.newaxis]
#       5 solver = Eof( tropics.data, wgts )
#
# NameError: name 'tropiclat' is not defined

# %% [markdown]
# ## Having done all the computations, just unpack and plot

# %%
variance=solver.varianceFraction() # this is same as eigenvals/sum(eigenvals)

plt.stem(variance*100.0,label="Variance")
plt.plot(variance.cumsum()*100.0,label="Cumulative Variance")
plt.xlim(0,10,1)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d6f5e85bd152> in <module>()
# ----> 1 variance=solver.varianceFraction() # this is same as eigenvals/sum(eigenvals)
#       2
#       3 plt.stem(variance*100.0,label="Variance")
#       4 plt.plot(variance.cumsum()*100.0,label="Cumulative Variance")
#       5 plt.xlim(0,10,1)
#
# NameError: name 'solver' is not defined

# %% [markdown]
# ### Look at the EOF structures and PC time series

# %%
# Retrieve the EOFs and PCs
eofs = solver.eofs()
pcs = solver.pcs()

# Retrieve the correlation between the leading PC time series 
# and the input SST anomalies at each grid point.
eofsasCorr = solver.eofsAsCorrelation()

# Retrieve the EOF expressed as the covariance between the leading  PC time series 
# and the input SST anomalies at each grid point.
eofsasCov = solver.eofsAsCovariance()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-bdb4f3058101> in <module>()
#       1 # Retrieve the EOFs and PCs
# ----> 2 eofs = solver.eofs()
#       3 pcs = solver.pcs()
#       4
#       5 # Retrieve the correlation between the leading PC time series
#
# NameError: name 'solver' is not defined

# %% [markdown]
# ## Is it a data reduction (compression) yet?

# %%
print(np.shape(eofs), np.shape(pcs))
print(np.shape(tropics9899.sst.data))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-6a877b072ba5> in <module>()
# ----> 1 print(np.shape(eofs), np.shape(pcs))
#       2 print(np.shape(tropics9899.sst.data))
#
# NameError: name 'eofs' is not defined

# %% [markdown]
# <a name="eofpcplots"></a>
# ## Let's look at the modes

# %%
def plot_map_ts(xydata,ts,lon,lat,time, label1, label2): 
    fig = plt.figure(figsize=(10, 4))

    ax = fig.add_subplot(121, projection=ccrs.PlateCarree())
    cmap = ax.contourf(lon, lat, xydata, 23, 
                 transform=ccrs.PlateCarree(), 
                 cmap='seismic')
    plt.colorbar(cmap, orientation='horizontal')
    ax.add_feature(cfeat.COASTLINE)
    ax.set_title(label1)
    
    ax2 = fig.add_subplot(122)
    ax2.plot(time, ts) 
    ax2.set_title(label2)

# %%
# Put the magnitude info into the PC for clarity of plot axis reading vs. colorbar reading
for MODE in [0,1,2,3]:
    xystd = np.std(eofs[MODE,:,:].ravel())
    print(xystd)
    plot_map_ts(eofs[MODE,:,:]/xystd, pcs[:,MODE]*xystd,
                                 tropics9899.lon,
                                 tropics9899.lat,
                                 tropics9899.time, 
            'EOF '+str(MODE+1), 'PC '+str(MODE+1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ffad3a4cd654> in <module>()
#       1 # Put the magnitude info into the PC for clarity of plot axis reading vs. colorbar reading
#       2 for MODE in [0,1,2,3]:
# ----> 3     xystd = np.std(eofs[MODE,:,:].ravel())
#       4     print(xystd)
#       5     plot_map_ts(eofs[MODE,:,:]/xystd, pcs[:,MODE]*xystd,
#
# NameError: name 'eofs' is not defined

# %% [markdown]
# <a name="orthogonality"></a>
# ## Check orthogonality

# %%
# corrcoef -- hey why not zero?
np.corrcoef(eofs[0,:,:].ravel(), eofs[1,:,:].ravel())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c6ddcf6a0526> in <module>()
#       1 # corrcoef -- hey why not zero?
# ----> 2 np.corrcoef(eofs[0,:,:].ravel(), eofs[1,:,:].ravel())
#
# NameError: name 'eofs' is not defined

# %%
# Ohhhh - because correlation subtracts the mean! 
# Really the EOFs are orthogonal as a VECTOR DOT PRODUCT, not ANOMALY PATTERN CORRELATION.
np.sum(eofs[0,:,:].ravel() * eofs[1,:,:].ravel())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-b3ff14e99c25> in <module>()
#       1 # Ohhhh - because correlation subtracts the mean!
#       2 # Really the EOFs are orthogonal as a VECTOR DOT PRODUCT, not ANOMALY PATTERN CORRELATION.
# ----> 3 np.sum(eofs[0,:,:].ravel() * eofs[1,:,:].ravel())
#
# NameError: name 'eofs' is not defined

# %%
# The PCs seem orthogonal even when means are removed
np.corrcoef(pcs[:,0], pcs[:,1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-222cd364b3d3> in <module>()
#       1 # The PCs seem orthogonal even when means are removed
# ----> 2 np.corrcoef(pcs[:,0], pcs[:,1])
#
# NameError: name 'pcs' is not defined

# %% [markdown]
# ## Truncated reconstructions: animated
# Grab some cells from Unidata's workshop notebook on making animations.
# You have to make one image, then animate the others

# %%
import matplotlib.animation as manimation
plt.rcParams['animation.html'] = 'jshtml'

# %%
def recon(TRUNC, time): 
    data = eofs[0,:,:] * pcs[time,0] # Always include the first one
    for i in range(1,TRUNC):
        data += eofs[i,:,:] * pcs[time,i]
    return(data)

# %%
# Make one figure to set the pattern

fig, ax = plt.subplots(figsize=(14,6))

im = ax.imshow(recon(1,0), animated=True, vmin=-4, vmax=4)
plt.colorbar(im, orientation='horizontal')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-680ef2c17961> in <module>()
#       3 fig, ax = plt.subplots(figsize=(14,6))
#       4
# ----> 5 im = ax.imshow(recon(1,0), animated=True, vmin=-4, vmax=4)
#       6 plt.colorbar(im, orientation='horizontal')
#
# <ipython-input-20-c5e753fa3c29> in recon(TRUNC, time)
#       1 def recon(TRUNC, time):
# ----> 2     data = eofs[0,:,:] * pcs[time,0] # Always include the first one
#       3     for i in range(1,TRUNC):
#       4         data += eofs[i,:,:] * pcs[time,i]
#       5     return(data)
#
# NameError: name 'eofs' is not defined

# %%
TRUNC = 23 ## Reconstruction truncation level (how many modes)

artists = []
for it in range(0, len(pcs[:,0])):   
    im = ax.imshow(recon(TRUNC,it), vmin=-4, vmax=4)
    ax.set_title('Truncation '+str(TRUNC)+' modes')
    artists.append([im]) # NOTE THE LIST

manimation.ArtistAnimation(fig, artists, interval=500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-83e79e791baf> in <module>()
#       2
#       3 artists = []
# ----> 4 for it in range(0, len(pcs[:,0])):
#       5     im = ax.imshow(recon(TRUNC,it), vmin=-4, vmax=4)
#       6     ax.set_title('Truncation '+str(TRUNC)+' modes')
#
# NameError: name 'pcs' is not defined

# %%
TRUNC = 3 ## Reconstruction truncation level (how many modes)

artists = []
for it in range(0, len(pcs[:,0])):   
    im = ax.imshow(recon(TRUNC,it), vmin=-4, vmax=4)
    ax.set_title('Truncation '+str(TRUNC)+' modes')
    artists.append([im]) # NOTE THE LIST

manimation.ArtistAnimation(fig, artists, interval=500)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-40eaef1f8c18> in <module>()
#       2
#       3 artists = []
# ----> 4 for it in range(0, len(pcs[:,0])):
#       5     im = ax.imshow(recon(TRUNC,it), vmin=-4, vmax=4)
#       6     ax.set_title('Truncation '+str(TRUNC)+' modes')
#
# NameError: name 'pcs' is not defined

# %% [markdown]
# ## Now we could do EOFs for ANY function of time and (perhaps 2D) space!
# Like a video... http://nbviewer.jupyter.org/github/MPOcanes/MPO624-2018/blob/master/assignments/module3-empiricaldecomp/EOF_of_video.ipynb
