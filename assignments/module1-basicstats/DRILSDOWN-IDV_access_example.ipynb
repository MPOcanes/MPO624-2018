# %% [markdown]
# <a name="top"></a>
# <div style="width:1000 px">
#
# <div style="float:right; width:98 px; height:98px;">
# <img src="https://cdn.miami.edu/_assets-common/images/system/um-logo-gray-bg.png" alt="Miami Logo" style="height: 98px;">
# </div>
#
# <h1>MPO 624: Connecting Jupyter to IDV and Mapes' DRILSDOWN project</h1>
#
# <div style="clear:both"></div>
# </div>
#
# <hr style="height:2px;">
#
# ### Steps in using IDV to get and preview data you will analyze:
# 1. <a href="#drilsdown">Load (or reload) the DRILSDOWN extension</a>

# %% [markdown]
# ------------
# ## To use the IDV from a notebook, (re)load the extension:

# %%
# %reload_ext drilsdown
# Out:
# VBox(children=(HTML(value='<h3>iPython-IDV Control Panel</h3>'), HBox(children=(HTML(value='<b>Resources:</b>'), Dropdown(options={'The Mapes IDV Collection': '45e3b50b-dbe2-408b-a6c2-2c009749cd53', 'Geode Systems Drilsdown Collection': '12704a38-9a06-4989-aac4-dafbbe13a675', 'NOAA-ESRL-PSD Climate Data Repository': 'f8d470f4-a072-4c1e-809e-d6116a393818', 'Unidata THREDDS Data Server': 'http://thredds.ucar.edu/thredds/catalog.xml', 'Unidata RAMADDA Server': '0', 'University of Miami THREDDS Data Server': 'http://weather.rsmas.miami.edu/thredds/catalog.xml', 'Local Files': '.'}, value='45e3b50b-dbe2-408b-a6c2-2c009749cd53'), Button(description='List', style=ButtonStyle(), tooltip='List'))), HBox(children=(HTML(value='<b>Search for:</b>'), Text(value='', layout=Layout(width='150px'), placeholder='IDV bundle'), Text(value='', layout=Layout(width='150px'), placeholder='Case Study or folder'), Text(value='', layout=Layout(width='150px'), placeholder='Gridded data files'), Text(value='', layout=Layout(width='150px'), placeholder='All'))), HBox(children=(Button(description='Run IDV', style=ButtonStyle(), tooltip='Run IDV'), Button(description='Make Image', style=ButtonStyle(), tooltip='Make Image'), Button(description='Make Movie', style=ButtonStyle(), tooltip='Make Movie'), Button(description='Save Bundle', style=ButtonStyle(), tooltip='Save Bundle'), Checkbox(value=False, description='Publish'))), HBox(children=(Button(description='Clear Outputs', style=ButtonStyle(), tooltip='Clear Outputs'), Button(description='Commands Help', style=ButtonStyle(), tooltip='Commands Help'), Label(value='')))))
# VBox(children=(HTML(value='<b><img src=https://www.esrl.noaa.gov/psd/repository/icons/folder.png> <a target=self href=https://www.esrl.noaa.gov/psd/repository/entry/show?entryid=f8d470f4-a072-4c1e-809e-d6116a393818>Public</a></b><br>'), HBox(children=(HTML(value='&nbsp;&nbsp;&nbsp;'), HTML(value='<span style=font-family:monospace;><img src=https://www.esrl.noaa.gov/psd/repository/icons/folder.png> <a target=ramadda title="Climate Assessment Resources" href="https://www.esrl.noaa.gov/psd/repository/entry/show?entryid=e5555a12-84f8-4bc6-86e3-17b51124c459">Climate&nbsp;Assessment&nbsp;Resour</a></span>'), Button(description='List', style=ButtonStyle(), tooltip='List'), Button(description='Load Catalog', style=ButtonStyle(), tooltip='Load Catalog'))), HBox(children=(HTML(value='&nbsp;&nbsp;&nbsp;'), HTML(value='<span style=font-family:monospace;><img src=https://www.esrl.noaa.gov/psd/repository/icons/folder.png> <a target=ramadda title="Interpreting Climate Conditions - Case Studies" href="https://www.esrl.noaa.gov/psd/repository/entry/show?entryid=b39bda59-881e-4ba1-b7ff-3613dce688ec">Interpreting&nbsp;Climate&nbsp;Cond</a></span>'), Button(description='List', style=ButtonStyle(), tooltip='List'), Button(description='Load Catalog', style=ButtonStyle(), tooltip='Load Catalog'))), HBox(children=(HTML(value='&nbsp;&nbsp;&nbsp;'), HTML(value='<span style=font-family:monospace;><img src=https://www.esrl.noaa.gov/psd/repository/icons/folder.png> <a target=ramadda title="PSD Datasets" href="https://www.esrl.noaa.gov/psd/repository/entry/show?entryid=e18f0d6f-743f-42ff-8aad-0e152357641b">PSD&nbsp;Datasets&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</a></span>'), Button(description='List', style=ButtonStyle(), tooltip='List'), Button(description='Load Catalog', style=ButtonStyle(), tooltip='Load Catalog'))), HBox(children=(HTML(value='&nbsp;&nbsp;&nbsp;'), HTML(value='<span style=font-family:monospace;><img src=https://www.esrl.noaa.gov/psd/repository/icons/folder.png> <a target=ramadda title="Visualizations" href="https://www.esrl.noaa.gov/psd/repository/entry/show?entryid=4bd472d0-3141-4d55-b69a-d4154893d4c3">Visualizations&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</a></span>'), Button(description='List', style=ButtonStyle(), tooltip='List'), Button(description='Load Catalog', style=ButtonStyle(), tooltip='Load Catalog')))))
# VBox(children=(HTML(value='<b>Search Results:</b> weather <br>'),))
# HTML(value='<b>No entries found</b>')
# VBox(children=(HTML(value='<b>Search Results:</b> vort <br>'), HBox(children=(HTML(value='&nbsp;&nbsp;&nbsp;'), HTML(value='<span style=font-family:monospace;><img src=http://weather.rsmas.miami.edu/repository/idv/idv.gif> <a target=ramadda title="500mb_topography_and_vorticity" href="http://weather.rsmas.miami.edu/repository/entry/show?entryid=478f9c53-27ea-4814-b9f5-fa85ff41ee30">500mb_topography_and_vort</a></span>'), Button(description='Load bundle', style=ButtonStyle(), tooltip='Load bundle'), Button(description='Set URL', style=ButtonStyle(), tooltip='Set URL'), HTML(value='<a target=ramadda href="http://weather.rsmas.miami.edu/repository/entry/show/?output=idv.islform&entryid=478f9c53-27ea-4814-b9f5-fa85ff41ee30">Subset Bundle</a>'))), HBox(children=(HTML(value='&nbsp;&nbsp;&nbsp;'), HTML(value='<span style=font-family:monospace;><img src=http://weather.rsmas.miami.edu/repository/idv/idv.gif> <a target=ramadda title="CONUS_jet_vort_xsec_sounding_3days" href="http://weather.rsmas.miami.edu/repository/entry/show?entryid=282471fb-6e9b-4d4d-a8bc-c59828b242f7">CONUS_jet_vort_xsec_sound</a></span>'), Button(description='Load bundle', style=ButtonStyle(), tooltip='Load bundle'), Button(description='Set URL', style=ButtonStyle(), tooltip='Set URL'), HTML(value='<a target=ramadda href="http://weather.rsmas.miami.edu/repository/entry/show/?output=idv.islform&entryid=282471fb-6e9b-4d4d-a8bc-c59828b242f7">Subset Bundle</a>'))), HBox(children=(HTML(value='&nbsp;&nbsp;&nbsp;'), HTML(value='<span style=font-family:monospace;><img src=http://weather.rsmas.miami.edu/repository/idv/idv.gif> <a target=ramadda title="CONUS_jet_vort_xsec_sounding_3days" href="http://weather.rsmas.miami.edu/repository/entry/show?entryid=5ec591cc-cffa-4fdf-b819-6c0f793a9ac8">CONUS_jet_vort_xsec_sound</a></span>'), Button(description='Load bundle', style=ButtonStyle(), tooltip='Load bundle'), Button(description='Set URL', style=ButtonStyle(), tooltip='Set URL'), HTML(value='<a target=ramadda href="http://weather.rsmas.miami.edu/repository/entry/show/?output=idv.islform&entryid=5ec591cc-cffa-4fdf-b819-6c0f793a9ac8">Subset Bundle</a>'))), HBox(children=(HTML(value='&nbsp;&nbsp;&nbsp;'), HTML(value='<span style=font-family:monospace;><img src=http://weather.rsmas.miami.edu/repository/idv/idv.gif> <a target=ramadda title="CONUS_jet_vort_xsec_sounding_3days" href="http://weather.rsmas.miami.edu/repository/entry/show?entryid=b11c3e51-d1ed-4ede-98ee-912f9caec3af">CONUS_jet_vort_xsec_sound</a></span>'), Button(description='Load bundle', style=ButtonStyle(), tooltip='Load bundle'), Button(description='Set URL', style=ButtonStyle(), tooltip='Set URL'), HTML(value='<a target=ramadda href="http://weather.rsmas.miami.edu/repository/entry/show/?output=idv.islform&entryid=b11c3e51-d1ed-4ede-98ee-912f9caec3af">Subset Bundle</a>'))), HBox(children=(HTML(value='&nbsp;&nbsp;&nbsp;'), HTML(value='<span style=font-family:monospace;><img src=http://weather.rsmas.miami.edu/repository/idv/idv.gif> <a target=ramadda title="ERAI_3D_RDA_forTeleporting_3dAbsVort" href="http://weather.rsmas.miami.edu/repository/entry/show?entryid=7cbf722d-9b3a-40f9-8336-11dc6a779113">ERAI_3D_RDA_forTeleportin</a></span>'), Button(description='Load bundle', style=ButtonStyle(), tooltip='Load bundle'), Button(description='Set URL', style=ButtonStyle(), tooltip='Set URL'), HTML(value='<a target=ramadda href="http://weather.rsmas.miami.edu/repository/entry/show/?output=idv.islform&entryid=7cbf722d-9b3a-40f9-8336-11dc6a779113">Subset Bundle</a>'))), HBox(children=(HTML(value='&nbsp;&nbsp;&nbsp;'), HTML(value='<span style=font-family:monospace;><img src=http://weather.rsmas.miami.edu/repository/idv/idv.gif> <a target=ramadda title="EquatorialVortex" href="http://weather.rsmas.miami.edu/repository/entry/show?entryid=54009579-0753-4655-9222-14a0ad7f6513">EquatorialVortex&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</a></span>'), Button(description='Load bundle', style=ButtonStyle(), tooltip='Load bundle' ...
# Starting IDV: /Applications/IDV_5.4u1/runIDV

# %%
# %make_ui

# %% [markdown]
# # Write for humans

# %%
# %make_image

# %% [markdown]
# ## Suppose we get an OpenDAP link -- use xarray to query it

# %%
import xarray as xr

xr_sst = xr.open_dataset('https://www.esrl.noaa.gov/psd/repository/opendap/ff6d272e-e941-42ed-be5f-a52a13047fc0/entry.das')
xr_sst
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 120, lon: 300, time: 365)
# Coordinates:
#   * lon      (lon) float32 230.125 230.375 230.625 230.875 231.125 231.375 ...
#   * time     (time) datetime64[ns] 1950-01-01 1950-01-02 1950-01-03 ...
#   * lat      (lat) float32 20.125 20.375 20.625 20.875 21.125 21.375 21.625 ...
# Data variables:
#     precip   (time, lat, lon) float64 ...
# Attributes:
#     title:                           CPC Unified Gauge-Based Analysis of Dail...
#     Conventions:                     COARDS
#     description:                     Gridded daily Precipitation
#     platform:                        Observations
#     Comments:                        Preciptation is accumulated from 12z of ...
#     history:                         originally created V1.0 starting 04/2010...
#     dataset_title:                   CPC Unified Gauge-Based Analysis of Dail...
#     References:                      http://www.esrl.noaa.gov/psd/data/gridde...
#     DODS_EXTRA.Unlimited_Dimension:  time
