# %%
import os
import sys
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from netCDF4 import Dataset
from mpl_toolkits import mplot3d

# %%
#Reading Data
data_direc = (r"C:\\Users\\Atlas\\Desktop\\Data_for_Python\\CONTRAST\\")

nc_file = Dataset(data_direc+'CONTRAST-AWAS-MERGE_GV_20140124_R1_rf06.nc')

# %%
print(nc_file.variables.keys())
# Out:
# odict_keys(['Time', 'Time_UTC', 'FLT_HH', 'FLT_MM', 'FLT_SS', 'UTC_HH', 'UTC_MM', 'UTC_SS', 'GALT_A', 'GGALT', 'GGEOIDHT', 'GGLAT', 'GGLON', 'GGQUAL', 'GGSPD', 'PITCH', 'RICE', 'ROLL', 'THDG', 'VISBC', 'VISTC', 'ATX', 'CONCD_RWOO', 'CONCU100_RWOI', 'CONCU500_RWOI', 'CONCU_RWOI', 'CONCV_VXL', 'DBARD_RWOO', 'DBARU_RWOI', 'DPXC', 'DP_DPL', 'DP_DPR', 'DP_VXL', 'EW_DPL', 'EW_DPR', 'EW_VXL', 'LATC', 'LONC', 'MR', 'PALT', 'PALTF', 'PLWCC', 'PLWCD_RWOO', 'PSXC', 'RHODT', 'RHUM', 'SOLAZ', 'SOLDE', 'SOLEL', 'SOLZE', 'TASX', 'THETA', 'THETAE', 'THETAQ', 'THETAV', 'TVIR', 'UIC', 'VIC', 'VMR_VXL', 'WDC', 'WIC', 'WSC', 'Profile_Number', 'Profile_Direction', 'C2H6_Ethane', 'C2H2_Ethyne', 'C3H8_Propane', 'C4H10_Isobutane', 'C4H10_nButane', 'C5H12_Isopentane', 'C5H12_nPentane', 'C5H8_Isoprene', 'C6H6_Benzene', 'OCS_Carbonyl_sulfide', 'C2H6S_Dimethyl_sulfide', 'CCl2F2_CFC_12', 'CCl3F_CFC_11', 'CCl2FCCl2F_CFC112', 'CCl3CClF2_CFC_112a', 'C2Cl3F3_CFC_113', 'C2Cl2F4_CFC_114', 'CHClF2_HCFC_22', 'CH3CClF2_HCFC_142b', 'CH3CCl2F_HCFC_141b', 'CH2FCF3_HFC_134a', 'C4H5F5_HFC365mfc', 'CH3Cl_Methyl_chloride', 'CH3Br_Methyl_bromide', 'CH3I_Methyl_iodide', 'CH2Cl2_Methylene_chloride', 'CHCl3_Chloroform', 'CH3CCl3_Methyl_chloroform', 'CCl4_Carbon_tetrachloride', 'C2H4Cl2_1_2_Dichloroethane', 'C2HCl3_Trichloroethylene', 'C2Cl4_Tetrachloroethylene', 'C6H5Cl_Chlorobenzene', 'CBrClF2_Halon_1211', 'C2Br2F4_Halon_2402', 'CH2BrCl_Bromochloromethane', 'CH2Br2_Methylene_bromide', 'CHBrCl2_Bromodichloromethane', 'CHBr2Cl_Dibromochloromethane', 'CHBr3_Bromoform', 'CH3ONO2_Methyl_nitrate', 'C2H5ONO2_Ethyl_nitrate', 'C3H7NO3_Isopropyl_nitrate', 'C4H9NO3_2_Butyl_nitrate', 'C4H9NO3_n_Butyl_nitrate', 'C5H11NO3_3_pentyl_nitrate', 'C5H11NO3_2_pentyl_nitrate', 'CO', 'CO2', 'Methane', 'DOAS_BrO', 'DOAS_delta_BrO', 'BrO', 'HOBr+Br2', 'Br_key', 'N2O5', 'O3->O2+O(1D)', 'NO2->NO+O(3P)', 'H2O2->2OH', 'N2O5->NO3+NO2', 'HNO2->OH+NO', 'HNO3->OH+NO2', 'HNO4->HO2+NO2', 'CH2O->H+HCO', 'CH2O->H2+CO', 'CH3CHO->CH3+HCO', 'C2H5CHO->C2H5+HCO', 'CH3OOH->CH3O+OH', 'CH3ONO2->CH3O+NO2', 'CH3CH2ONO2->CH3CH2O+NO2', 'CH3CO(OONO2)[PAN]->CH3CO(OO)+NO2', 'CH3CO(OONO2)[PAN]->CH3CO(O)+NO3', 'CH2=C(CH3)CHO->Products', 'CH3COCH=CH2->Products', 'CH3COCH3->CH3CO+CH3', 'CH3COCH2CH3->CH3CO+CH2CH3', 'CHOCHO->HCO+HCO', 'CHOCHO->H2+2CO', 'CHOCHO->CH2O+CO', 'CH3COCHO->CH3CO+HCO', 'Cl2->Cl+Cl', 'ClO->Cl+O(3P)', 'ClNO2->Cl+NO2', 'ClONO->Cl+NO2', 'ClONO2->Cl+NO3', 'ClONO2->ClO+NO2', 'Br2->Br+Br', 'BrO->Br+O', 'HOBr->OH+Br', 'BrNO->Br+NO', 'BrONO->Br+NO2', 'BrONO->BrO+NO', 'BrNO2->Br+NO2', 'BrONO2->BrO+NO2', 'BrONO2->Br+NO3', 'BrCl->Br+Cl', 'CHBr3->Products', 'CH3CH2CH2CHO->C3H7+HCO', 'CH3CH2CH2CHO->C2H4+CH2CHOH', 'Br2O->Products', 'HCHO', 'NO_pptv', 'NO2_pptv', 'XNO2_pptv', 'O3_ppbv', 'NO_precErr_pptv', 'NO_biasErr_pptv', 'NO2_precErr_pptv', 'NO2_biasErr_pptv', 'O3_precErr_ppbv', 'O3_biasErr_ppbv', 'C3H8', 'CH2O', 'OCS', 'CFC12', 'CFC114', 'HCN', 'i_Butane', 'n_Butane', 'Methyl_Chloride', 'Acetaldehyde', 'i_Butene_1_Butene', 'Methyl_Bromide', 'i_Pentane', 'n_Pentane', 'Methanol', 'Ethanol', 'Acrolein', 'Isoprene', 'Methyl_Iodide', 'DMS', 'Bromoethane', 'CFC11', 'CFC113', 'Propanal', 'Acetone', '2_Methylpentane', '3_Methylpentane', 'n_Hexane', 'Dichloromethane', '2_Propanol', 'CH3CN', 'MethylNitrate', 'PAN', 'MACR', 'MVK', '3_MethylFuran', 'Butanal', 'MEK', 'Ethyl_Iodide', 'MTBE', 'Chloroform', 'Carbon_Tetrachloride', 'Bromochloromethane', 'EthylNitrate', 'I_PropylNitrate', 'MBO', 'Benzene', 'n_Heptane', 'Pentanal', '2_Pentanone', '3_Pentanone', 'Bromodichloromethane', 'Dibromomethane', 'Chloroiodomethane', 'tert_ButylNitrate', 'I_ButylNitrate', '2_ButylNitrate_n_ButylNitrate', '2_PentylNitrate_3_PentylNitrate', 'Toluene', 'Ethylbenzene_m_p_Xylene', 'o_Xylene', 'Tetrachloroethylene', 'Dibromochloromethane', 'Bromoiodomethane', 'Chlorobenzene', 'Bromoform', 'Alpha_Pinene', 'Camphene', 'Beta_Pinene', 'd_Limonene_3_Carene', 'Alpha_Terpinene', 'Para_Cymene', '1_2_4_Trimethylbenzene', '1_3_5_Trimethylbenzene', '1_2_3_Trimethy ...

# %%
time = nc_file.variables['Time'][:]
lat = nc_file.variables['GGLAT'][:]
lon = nc_file.variables['GGLON'][:]
altitude = nc_file.variables['GGALT'][:]
ozone = nc_file.variables['O3_ppbv'][:]

# %%
#Creating a 3D plot

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Data for three-dimensional scattered points
x=lat
y=lon
z=altitude

ax.plot(x, y, z)
