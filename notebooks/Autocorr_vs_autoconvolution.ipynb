# %% [markdown]
# # Autoconvolution vs. auto-correlation.
# # Are they same?

# %%
import numpy as np
import pandas as pd
from netCDF4 import Dataset
import matplotlib.pyplot as plt
from matplotlib import gridspec
from scipy import signal
from scipy.signal import butter, lfilter, freqz
from numpy import arange, sin, pi, angle

# %%
x=np.array([1.0,2.0,3.0])
y=np.correlate(x,x,"full")
plt.plot(y,label='Auto-correlation')
z=np.convolve(x,x)
plt.plot(z,label='Auto-convolution')
plt.legend(loc='upper left')
plt.show()
print()

# %% [markdown]
# # Discrete calculation in time domain

# %% [markdown]
# ![alt text](https://github.com/mampi-sarkar/jupyter/blob/master/Auto_corr.JPG?raw=true "Title")
# ![alt text](https://github.com/mampi-sarkar/jupyter/blob/master/Auto_conv.JPG?raw=true "Title")
